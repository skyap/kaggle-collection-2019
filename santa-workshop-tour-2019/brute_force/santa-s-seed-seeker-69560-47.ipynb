# %% [markdown]
# - Starter submission from https://www.kaggle.com/vipito/santa-ip
# - KT: https://www.kaggle.com/c/santa-workshop-tour-2019/discussion/119858
# - Cost function: https://www.kaggle.com/nickel/santa-s-2019-fast-pythonic-cost-23-s

# %%
import numpy as np
import pandas as pd
from numba import njit, prange
from tqdm import notebook,tqdm
from tqdm import trange

# %%
data = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/family_data.csv', index_col='family_id')
family_size = data.n_people.values.astype(np.int8)

penalties = np.asarray([
    [
        0,
        50,
        50 + 9 * n,
        100 + 9 * n,
        200 + 9 * n,
        200 + 18 * n,
        300 + 18 * n,
        300 + 36 * n,
        400 + 36 * n,
        500 + 36 * n + 199 * n,
        500 + 36 * n + 398 * n
    ] for n in range(family_size.max() + 1)
])

family_cost_matrix = np.concatenate(data.n_people.apply(lambda n: np.repeat(penalties[n, 10], 100).reshape(1, 100)))

for fam in data.index:
    for choice_order, day in enumerate(data.loc[fam].drop("n_people")):
        family_cost_matrix[fam, day - 1] = penalties[data.loc[fam, "n_people"], choice_order]


accounting_cost_matrix = np.zeros((500, 500))
for n in range(accounting_cost_matrix.shape[0]):
    for diff in range(accounting_cost_matrix.shape[1]):
        accounting_cost_matrix[n, diff] = max(0, (n - 125.0) / 400.0 * n**(0.5 + diff / 50.0))


@njit(fastmath=True)
def cost_function(prediction, family_size=family_size, family_cost_matrix=family_cost_matrix, accounting_cost_matrix=accounting_cost_matrix):
    N_DAYS = family_cost_matrix.shape[1]
    MAX_OCCUPANCY = 300
    MIN_OCCUPANCY = 125
    penalty = 0
    daily_occupancy = np.zeros(N_DAYS + 1, dtype=np.int16)
    for i, (pred, n) in enumerate(zip(prediction, family_size)):
        daily_occupancy[pred - 1] += n
        penalty += family_cost_matrix[i, pred - 1]

    accounting_cost = 0
    n_low = 0
    n_high = 0
    daily_occupancy[-1] = daily_occupancy[-2]
    for day in range(N_DAYS):
        n_next = daily_occupancy[day + 1]
        n = daily_occupancy[day]
        n_high += (n > MAX_OCCUPANCY)
        n_low += (n < MIN_OCCUPANCY)
        diff = abs(n - n_next)
        accounting_cost += accounting_cost_matrix[n, diff]

    return np.asarray([penalty, accounting_cost, n_low, n_high])


def score(prediction):
    fc, ac, l, h = cost_function(prediction, family_size, family_cost_matrix, accounting_cost_matrix)
    return (fc + ac) + (l + h) * 1000000

# %%
SELECTED = 'submission69560.47.csv'
pred = pd.read_csv(f'/kaggle/input/santa-output/{SELECTED}', index_col='family_id').assigned_day.values
init_score = score(pred)
print(init_score)
fam = pd.read_csv("/kaggle/input/santa-workshop-tour-2019/family_data.csv")
sub = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/sample_submission.csv')
sub.assigned_day = pred
sub.to_csv(f'submission_{init_score}.csv',index=False)
pref = fam.values[:,1:-1]
# Out:
# 69560.47837780278

# %%
def seed_finding(seed, prediction_input):
    prediction = prediction_input.copy()
    np.random.seed(seed)
    best_score = score(prediction)
    original_score = best_score
    print("SEED: {}   ORIGINAL SCORE: {}".format(seed, original_score))
#     bar = trange(100,leave=True)
    for t in range(100):
        for i in range(5000):
            for j in range(10):
                di = prediction[i]
                prediction[i] = pref[i, j]
                cur_score = score(prediction)

                KT = 1
                if t < 5:
                    KT = 1.5
                elif t < 10:
                    KT = 4.5
                else:
                    if cur_score > best_score + 100:
                        KT = 3
                    elif cur_score > best_score + 50 :
                        KT = 2.75
                    elif cur_score > best_score + 20:
                        KT = 2.5
                    elif cur_score > best_score + 10:
                        KT = 2
                    elif cur_score > best_score:
                        KT = 1.5
                    else:
                        KT = 1

                prob = np.exp(-(cur_score - best_score) / KT)
                if np.random.rand() < prob:
                    best_score = cur_score
                else:
                    prediction[i] = di
#         bar.set_description(f"{best_score:,.0f}")
#         bar.refresh()
        if best_score < original_score:
            print("NEW BEST SCORE on seed {}: {}".format(seed, best_score))
            sub.assigned_day = prediction
            sub.to_csv(f'submission_{best_score}.csv', index=False)
#             sub.to_csv(f'submission.csv', index=False)
            break

    if best_score >= original_score:
        print("UNLUCKY on seed {} for 100 runs, no impovement.".format(seed))

    return prediction, best_score

# %% [markdown]
# # Greedy Search

# %%
# best = pred
# previous_score = score(best)
# best_score = previous_score
# early_stop = 0
# epochs = 200
# for i in notebook.tqdm(range(epochs)):
#     for j in notebook.tqdm(range(5000),leave=False):
#         ch = data.iloc[j,:-1].values
#         for k in range(10):
#             ori,best[j] = best[j],ch[k]
#             current_score = score(best)
#             if current_score<best_score:
#                 best_score = current_score
#             else:
#                 best[j] = ori
#     print(f"epoch {i}/{epochs} -- best_score: {best_score:,.0f}")
#     if round(best_score) >= round(previous_score):
#         print("not improving")
#         break
#     else:
#         previous_score = best_score
                
# score(best)

# %%
# from tqdm import trange
# best_score = score(best)
# previous_score = best_score
# epochs = 1
# t = trange(5000,leave=True)
# for i in range(epochs):
#     for j in t:
#         for k in range(j,5000):
#             best[j],best[k] = best[k],best[j]
#             current_score = score(best)
#             if current_score<best_score:
#                 best_score = current_score
#             else:
#                 best[j],best[k] = best[k],best[j]
#         t.set_description(f"epoch {i}/{epochs} -- best_score: {best_score:,.0f}")
#         t.refresh()
#     if round(best_score) >= round(previous_score):
#         print("not improving")
#         break
#     else:
#         previous_score = best_score
                
# score(best)

# %%
best_score = init_score

for seed in notebook.tqdm(range(1200,1300)):
    pred, best_score = seed_finding(seed, pred)
    if best_score < init_score:
        init_score = best_score
        
    else:
        best_score = init_score
    pred = pd.read_csv(f'submission_{best_score}.csv', index_col='family_id').assigned_day.values
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# SEED: 1200   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1200 for 100 runs, no impovement.
# SEED: 1201   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1201 for 100 runs, no impovement.
# SEED: 1202   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1202 for 100 runs, no impovement.
# SEED: 1203   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1203 for 100 runs, no impovement.
# SEED: 1204   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1204 for 100 runs, no impovement.
# SEED: 1205   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1205 for 100 runs, no impovement.
# SEED: 1206   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1206 for 100 runs, no impovement.
# SEED: 1207   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1207 for 100 runs, no impovement.
# SEED: 1208   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1208 for 100 runs, no impovement.
# SEED: 1209   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1209 for 100 runs, no impovement.
# SEED: 1210   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1210 for 100 runs, no impovement.
# SEED: 1211   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1211 for 100 runs, no impovement.
# SEED: 1212   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1212 for 100 runs, no impovement.
# SEED: 1213   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1213 for 100 runs, no impovement.
# SEED: 1214   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1214 for 100 runs, no impovement.
# SEED: 1215   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1215 for 100 runs, no impovement.
# SEED: 1216   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1216 for 100 runs, no impovement.
# SEED: 1217   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1217 for 100 runs, no impovement.
# SEED: 1218   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1218 for 100 runs, no impovement.
# SEED: 1219   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1219 for 100 runs, no impovement.
# SEED: 1220   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1220 for 100 runs, no impovement.
# SEED: 1221   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1221 for 100 runs, no impovement.
# SEED: 1222   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1222 for 100 runs, no impovement.
# SEED: 1223   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1223 for 100 runs, no impovement.
# SEED: 1224   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1224 for 100 runs, no impovement.
# SEED: 1225   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1225 for 100 runs, no impovement.
# SEED: 1226   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1226 for 100 runs, no impovement.
# SEED: 1227   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1227 for 100 runs, no impovement.
# SEED: 1228   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1228 for 100 runs, no impovement.
# SEED: 1229   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1229 for 100 runs, no impovement.
# SEED: 1230   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1230 for 100 runs, no impovement.
# SEED: 1231   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1231 for 100 runs, no impovement.
# SEED: 1232   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1232 for 100 runs, no impovement.
# SEED: 1233   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1233 for 100 runs, no impovement.
# SEED: 1234   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1234 for 100 runs, no impovement.
# SEED: 1235   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1235 for 100 runs, no impovement.
# SEED: 1236   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1236 for 100 runs, no impovement.
# SEED: 1237   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1237 for 100 runs, no impovement.
# SEED: 1238   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1238 for 100 runs, no impovement.
# SEED: 1239   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1239 for 100 runs, no impovement.
# SEED: 1240   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1240 for 100 runs, no impovement.
# SEED: 1241   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1241 for 100 runs, no impovement.
# SEED: 1242   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1242 for 100 runs, no impovement.
# SEED: 1243   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1243 for 100 runs, no impovement.
# SEED: 1244   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1244 for 100 runs, no impovement.
# SEED: 1245   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1245 for 100 runs, no impovement.
# SEED: 1246   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1246 for 100 runs, no impovement.
# SEED: 1247   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1247 for 100 runs, no impovement.
# SEED: 1248   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1248 for 100 runs, no impovement.
# SEED: 1249   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1249 for 100 runs, no impovement.
# SEED: 1250   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1250 for 100 runs, no impovement.
# SEED: 1251   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1251 for 100 runs, no impovement.
# SEED: 1252   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1252 for 100 runs, no impovement.
# SEED: 1253   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1253 for 100 runs, no impovement.
# SEED: 1254   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1254 for 100 runs, no impovement.
# SEED: 1255   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1255 for 100 runs, no impovement.
# SEED: 1256   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1256 for 100 runs, no impovement.
# SEED: 1257   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1257 for 100 runs, no impovement.
# SEED: 1258   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1258 for 100 runs, no impovement.
# SEED: 1259   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1259 for 100 runs, no impovement.
# SEED: 1260   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1260 for 100 runs, no impovement.
# SEED: 1261   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1261 for 100 runs, no impovement.
# SEED: 1262   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1262 for 100 runs, no impovement.
# SEED: 1263   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1263 for 100 runs, no impovement.
# SEED: 1264   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1264 for 100 runs, no impovement.
# SEED: 1265   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1265 for 100 runs, no impovement.
# SEED: 1266   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1266 for 100 runs, no impovement.
# SEED: 1267   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1267 for 100 runs, no impovement.
# SEED: 1268   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1268 for 100 runs, no impovement.
# SEED: 1269   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1269 for 100 runs, no impovement.
# SEED: 1270   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1270 for 100 runs, no impovement.
# SEED: 1271   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1271 for 100 runs, no impovement.
# SEED: 1272   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1272 for 100 runs, no impovement.
# SEED: 1273   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1273 for 100 runs, no impovement.
# SEED: 1274   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1274 for 100 runs, no impovement.
# SEED: 1275   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1275 for 100 runs, no impovement.
# SEED: 1276   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1276 for 100 runs, no impovement.
# SEED: 1277   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1277 for 100 runs, no impovement.
# SEED: 1278   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1278 for 100 runs, no impovement.
# SEED: 1279   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1279 for 100 runs, no impovement.
# SEED: 1280   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1280 for 100 runs, no impovement.
# SEED: 1281   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1281 for 100 runs, no impovement.
# SEED: 1282   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1282 for 100 runs, no impovement.
# SEED: 1283   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1283 for 100 runs, no impovement.
# SEED: 1284   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1284 for 100 runs, no impovement.
# SEED: 1285   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1285 for 100 runs, no impovement.
# SEED: 1286   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1286 for 100 runs, no impovement.
# SEED: 1287   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1287 for 100 runs, no impovement.
# SEED: 1288   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1288 for 100 runs, no impovement.
# SEED: 1289   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1289 for 100 runs, no impovement.
# SEED: 1290   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1290 for 100 runs, no impovement.
# SEED: 1291   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1291 for 100 runs, no impovement.
# SEED: 1292   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1292 for 100 runs, no impovement.
# SEED: 1293   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1293 for 100 runs, no impovement.
# SEED: 1294   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1294 for 100 runs, no impovement.
# SEED: 1295   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1295 for 100 runs, no impovement.
# SEED: 1296   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1296 for 100 runs, no impovement.
# SEED: 1297   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1297 for 100 runs, no impovement.
# SEED: 1298   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1298 for 100 runs, no impovement.
# SEED: 1299   ORIGINAL SCORE: 69560.47837780278
# UNLUCKY on seed 1299 for 100 runs, no impovement.

# %%
# !ls
# Out:
# __notebook__.ipynb  __output__.json  submission_69560.47837780278.csv
