# %% [markdown]
# - Starter submission from https://www.kaggle.com/vipito/santa-ip
# - KT: https://www.kaggle.com/c/santa-workshop-tour-2019/discussion/119858
# - Cost function: https://www.kaggle.com/nickel/santa-s-2019-fast-pythonic-cost-23-s

# %%
import numpy as np
import pandas as pd
from numba import njit, prange
from tqdm import notebook,tqdm
from tqdm import trange

# %%
data = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/family_data.csv', index_col='family_id')
family_size = data.n_people.values.astype(np.int8)

penalties = np.asarray([
    [
        0,
        50,
        50 + 9 * n,
        100 + 9 * n,
        200 + 9 * n,
        200 + 18 * n,
        300 + 18 * n,
        300 + 36 * n,
        400 + 36 * n,
        500 + 36 * n + 199 * n,
        500 + 36 * n + 398 * n
    ] for n in range(family_size.max() + 1)
])

family_cost_matrix = np.concatenate(data.n_people.apply(lambda n: np.repeat(penalties[n, 10], 100).reshape(1, 100)))

for fam in data.index:
    for choice_order, day in enumerate(data.loc[fam].drop("n_people")):
        family_cost_matrix[fam, day - 1] = penalties[data.loc[fam, "n_people"], choice_order]


accounting_cost_matrix = np.zeros((500, 500))
for n in range(accounting_cost_matrix.shape[0]):
    for diff in range(accounting_cost_matrix.shape[1]):
        accounting_cost_matrix[n, diff] = max(0, (n - 125.0) / 400.0 * n**(0.5 + diff / 50.0))


@njit(fastmath=True)
def cost_function(prediction, family_size=family_size, family_cost_matrix=family_cost_matrix, accounting_cost_matrix=accounting_cost_matrix):
    N_DAYS = family_cost_matrix.shape[1]
    MAX_OCCUPANCY = 300
    MIN_OCCUPANCY = 125
    penalty = 0
    daily_occupancy = np.zeros(N_DAYS + 1, dtype=np.int16)
    for i, (pred, n) in enumerate(zip(prediction, family_size)):
        daily_occupancy[pred - 1] += n
        penalty += family_cost_matrix[i, pred - 1]

    accounting_cost = 0
    n_low = 0
    n_high = 0
    daily_occupancy[-1] = daily_occupancy[-2]
    for day in range(N_DAYS):
        n_next = daily_occupancy[day + 1]
        n = daily_occupancy[day]
        n_high += (n > MAX_OCCUPANCY)
        n_low += (n < MIN_OCCUPANCY)
        diff = abs(n - n_next)
        accounting_cost += accounting_cost_matrix[n, diff]

    return np.asarray([penalty, accounting_cost, n_low, n_high])


def score(prediction):
    fc, ac, l, h = cost_function(prediction, family_size, family_cost_matrix, accounting_cost_matrix)
    return (fc + ac) + (l + h) * 1000000

# %%
SELECTED = 'submission69564.04.csv'
pred = pd.read_csv(f'/kaggle/input/santa-output/{SELECTED}', index_col='family_id').assigned_day.values
init_score = score(pred)
print(init_score)
fam = pd.read_csv("/kaggle/input/santa-workshop-tour-2019/family_data.csv")
sub = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/sample_submission.csv')
sub.assigned_day = pred
sub.to_csv(f'submission_{init_score}.csv',index=False)
pref = fam.values[:,1:-1]
# Out:
# 69564.04945628237

# %%
def seed_finding(seed, prediction_input):
    prediction = prediction_input.copy()
    np.random.seed(seed)
    best_score = score(prediction)
    original_score = best_score
    print("SEED: {}   ORIGINAL SCORE: {}".format(seed, original_score))
#     bar = trange(100,leave=True)
    for t in range(100):
        for i in range(5000):
            for j in range(10):
                di = prediction[i]
                prediction[i] = pref[i, j]
                cur_score = score(prediction)

                KT = 1
                if t < 5:
                    KT = 1.5
                elif t < 10:
                    KT = 4.5
                else:
                    if cur_score > best_score + 100:
                        KT = 3
                    elif cur_score > best_score + 50 :
                        KT = 2.75
                    elif cur_score > best_score + 20:
                        KT = 2.5
                    elif cur_score > best_score + 10:
                        KT = 2
                    elif cur_score > best_score:
                        KT = 1.5
                    else:
                        KT = 1

                prob = np.exp(-(cur_score - best_score) / KT)
                if np.random.rand() < prob:
                    best_score = cur_score
                else:
                    prediction[i] = di
#         bar.set_description(f"{best_score:,.0f}")
#         bar.refresh()
        if best_score < original_score:
            print("NEW BEST SCORE on seed {}: {}".format(seed, best_score))
            sub.assigned_day = prediction
            sub.to_csv(f'submission_{best_score}.csv', index=False)
#             sub.to_csv(f'submission.csv', index=False)
            break

    if best_score >= original_score:
        print("UNLUCKY on seed {} for 100 runs, no impovement.".format(seed))

    return prediction, best_score

# %% [markdown]
# # Greedy Search

# %%
# best = pred
# previous_score = score(best)
# best_score = previous_score
# early_stop = 0
# epochs = 200
# for i in notebook.tqdm(range(epochs)):
#     for j in notebook.tqdm(range(5000),leave=False):
#         ch = data.iloc[j,:-1].values
#         for k in range(10):
#             ori,best[j] = best[j],ch[k]
#             current_score = score(best)
#             if current_score<best_score:
#                 best_score = current_score
#             else:
#                 best[j] = ori
#     print(f"epoch {i}/{epochs} -- best_score: {best_score:,.0f}")
#     if round(best_score) >= round(previous_score):
#         print("not improving")
#         break
#     else:
#         previous_score = best_score
                
# score(best)

# %%
# from tqdm import trange
# best_score = score(best)
# previous_score = best_score
# epochs = 1
# t = trange(5000,leave=True)
# for i in range(epochs):
#     for j in t:
#         for k in range(j,5000):
#             best[j],best[k] = best[k],best[j]
#             current_score = score(best)
#             if current_score<best_score:
#                 best_score = current_score
#             else:
#                 best[j],best[k] = best[k],best[j]
#         t.set_description(f"epoch {i}/{epochs} -- best_score: {best_score:,.0f}")
#         t.refresh()
#     if round(best_score) >= round(previous_score):
#         print("not improving")
#         break
#     else:
#         previous_score = best_score
                
# score(best)

# %%
best_score = init_score

for seed in notebook.tqdm(range(300,400)):
    pred, best_score = seed_finding(seed, pred)
    if best_score < init_score:
        init_score = best_score
        
    else:
        best_score = init_score
    pred = pd.read_csv(f'submission_{best_score}.csv', index_col='family_id').assigned_day.values
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# SEED: 300   ORIGINAL SCORE: 69564.04945628237
# NEW BEST SCORE on seed 300: 69561.59910055793
# SEED: 301   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 301 for 100 runs, no impovement.
# SEED: 302   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 302 for 100 runs, no impovement.
# SEED: 303   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 303 for 100 runs, no impovement.
# SEED: 304   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 304 for 100 runs, no impovement.
# SEED: 305   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 305 for 100 runs, no impovement.
# SEED: 306   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 306 for 100 runs, no impovement.
# SEED: 307   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 307 for 100 runs, no impovement.
# SEED: 308   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 308 for 100 runs, no impovement.
# SEED: 309   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 309 for 100 runs, no impovement.
# SEED: 310   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 310 for 100 runs, no impovement.
# SEED: 311   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 311 for 100 runs, no impovement.
# SEED: 312   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 312 for 100 runs, no impovement.
# SEED: 313   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 313 for 100 runs, no impovement.
# SEED: 314   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 314 for 100 runs, no impovement.
# SEED: 315   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 315 for 100 runs, no impovement.
# SEED: 316   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 316 for 100 runs, no impovement.
# SEED: 317   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 317 for 100 runs, no impovement.
# SEED: 318   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 318 for 100 runs, no impovement.
# SEED: 319   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 319 for 100 runs, no impovement.
# SEED: 320   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 320 for 100 runs, no impovement.
# SEED: 321   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 321 for 100 runs, no impovement.
# SEED: 322   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 322 for 100 runs, no impovement.
# SEED: 323   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 323 for 100 runs, no impovement.
# SEED: 324   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 324 for 100 runs, no impovement.
# SEED: 325   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 325 for 100 runs, no impovement.
# SEED: 326   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 326 for 100 runs, no impovement.
# SEED: 327   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 327 for 100 runs, no impovement.
# SEED: 328   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 328 for 100 runs, no impovement.
# SEED: 329   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 329 for 100 runs, no impovement.
# SEED: 330   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 330 for 100 runs, no impovement.
# SEED: 331   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 331 for 100 runs, no impovement.
# SEED: 332   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 332 for 100 runs, no impovement.
# SEED: 333   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 333 for 100 runs, no impovement.
# SEED: 334   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 334 for 100 runs, no impovement.
# SEED: 335   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 335 for 100 runs, no impovement.
# SEED: 336   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 336 for 100 runs, no impovement.
# SEED: 337   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 337 for 100 runs, no impovement.
# SEED: 338   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 338 for 100 runs, no impovement.
# SEED: 339   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 339 for 100 runs, no impovement.
# SEED: 340   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 340 for 100 runs, no impovement.
# SEED: 341   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 341 for 100 runs, no impovement.
# SEED: 342   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 342 for 100 runs, no impovement.
# SEED: 343   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 343 for 100 runs, no impovement.
# SEED: 344   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 344 for 100 runs, no impovement.
# SEED: 345   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 345 for 100 runs, no impovement.
# SEED: 346   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 346 for 100 runs, no impovement.
# SEED: 347   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 347 for 100 runs, no impovement.
# SEED: 348   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 348 for 100 runs, no impovement.
# SEED: 349   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 349 for 100 runs, no impovement.
# SEED: 350   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 350 for 100 runs, no impovement.
# SEED: 351   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 351 for 100 runs, no impovement.
# SEED: 352   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 352 for 100 runs, no impovement.
# SEED: 353   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 353 for 100 runs, no impovement.
# SEED: 354   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 354 for 100 runs, no impovement.
# SEED: 355   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 355 for 100 runs, no impovement.
# SEED: 356   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 356 for 100 runs, no impovement.
# SEED: 357   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 357 for 100 runs, no impovement.
# SEED: 358   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 358 for 100 runs, no impovement.
# SEED: 359   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 359 for 100 runs, no impovement.
# SEED: 360   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 360 for 100 runs, no impovement.
# SEED: 361   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 361 for 100 runs, no impovement.
# SEED: 362   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 362 for 100 runs, no impovement.
# SEED: 363   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 363 for 100 runs, no impovement.
# SEED: 364   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 364 for 100 runs, no impovement.
# SEED: 365   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 365 for 100 runs, no impovement.
# SEED: 366   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 366 for 100 runs, no impovement.
# SEED: 367   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 367 for 100 runs, no impovement.
# SEED: 368   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 368 for 100 runs, no impovement.
# SEED: 369   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 369 for 100 runs, no impovement.
# SEED: 370   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 370 for 100 runs, no impovement.
# SEED: 371   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 371 for 100 runs, no impovement.
# SEED: 372   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 372 for 100 runs, no impovement.
# SEED: 373   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 373 for 100 runs, no impovement.
# SEED: 374   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 374 for 100 runs, no impovement.
# SEED: 375   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 375 for 100 runs, no impovement.
# SEED: 376   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 376 for 100 runs, no impovement.
# SEED: 377   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 377 for 100 runs, no impovement.
# SEED: 378   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 378 for 100 runs, no impovement.
# SEED: 379   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 379 for 100 runs, no impovement.
# SEED: 380   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 380 for 100 runs, no impovement.
# SEED: 381   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 381 for 100 runs, no impovement.
# SEED: 382   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 382 for 100 runs, no impovement.
# SEED: 383   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 383 for 100 runs, no impovement.
# SEED: 384   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 384 for 100 runs, no impovement.
# SEED: 385   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 385 for 100 runs, no impovement.
# SEED: 386   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 386 for 100 runs, no impovement.
# SEED: 387   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 387 for 100 runs, no impovement.
# SEED: 388   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 388 for 100 runs, no impovement.
# SEED: 389   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 389 for 100 runs, no impovement.
# SEED: 390   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 390 for 100 runs, no impovement.
# SEED: 391   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 391 for 100 runs, no impovement.
# SEED: 392   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 392 for 100 runs, no impovement.
# SEED: 393   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 393 for 100 runs, no impovement.
# SEED: 394   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 394 for 100 runs, no impovement.
# SEED: 395   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 395 for 100 runs, no impovement.
# SEED: 396   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 396 for 100 runs, no impovement.
# SEED: 397   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 397 for 100 runs, no impovement.
# SEED: 398   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 398 for 100 runs, no impovement.
# SEED: 399   ORIGINAL SCORE: 69561.59910055793
# UNLUCKY on seed 399 for 100 runs, no impovement.

# %%
# !ls
# Out:
# __notebook__.ipynb  submission_69561.59910055793.csv
# __output__.json     submission_69564.04945628237.csv
